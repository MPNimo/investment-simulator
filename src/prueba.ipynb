# %%
import os
from datetime import datetime
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

END_DATE = datetime.today().strftime("%Y-%m-%d")

apple = yf.download('AAPL', start='2020-01-01', end=END_DATE, threads=False)

# apple['9_MA'] = apple['Close'].rolling(window=9).mean()
# apple['20_MA'] = apple['Close'].rolling(window=20).mean()
# Out:
# C:\Users\Magdala Pérez Nimo\AppData\Local\Temp\ipykernel_7216\2176991175.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   apple = yf.download('AAPL', start='2020-01-01', end=END_DATE, threads=False)
# Failed to get ticker 'AAPL' reason: Failed to perform, curl: (77) error setting certificate verify locations:  CAfile: c:\Users\Magdala Pérez Nimo\Documents\Projects\Proyectos\venv\Lib\site-packages\certifi\cacert.pem CApath: none. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: SSLError('Failed to perform, curl: (77) error setting certificate verify locations:  CAfile: c:\\Users\\Magdala Pérez Nimo\\Documents\\Projects\\Proyectos\\venv\\Lib\\site-packages\\certifi\\cacert.pem CApath: none. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')

# %%
apple.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: [(Adj Close, AAPL), (Close, AAPL), (High, AAPL), (Low, AAPL), (Open, AAPL), (Volume, AAPL)]
# Index: []>

# %% [markdown]
# No trae los datos de yfinance --> pruebas de a ver que está pasando.
